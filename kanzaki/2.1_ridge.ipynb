# %% [markdown]
# <h1>Check training data

# %%
import pandas as pd

# %%
df=pd.read_csv( 'train.tsv', delimiter='\t' )

# %%
df.head(100)
# Out:
#     train_id                                      name  item_condition_id  \
# 0          0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1          1          Razer BlackWidow Chroma Keyboard                  3
# 2          2                            AVA-VIV Blouse                  1
# 3          3                     Leather Horse Statues                  1
# 4          4                      24K GOLD plated rose                  1
# 5          5          Bundled items requested for Ruie                  3
# 6          6        Acacia pacific tides santorini top                  3
# 7          7      Girls cheer and tumbling bundle of 7                  3
# 8          8                     Girls Nike Pro shorts                  3
# 9          9    Porcelain clown doll checker pants VTG                  3
# 10        10                           Smashbox primer                  2
# 11        11                    New vs pi k body mists                  1
# 12        12                        Black Skater dress                  2
# 13        13                      Sharpener and eraser                  1
# 14        14        HOLD for Dogs2016 Minnetonka boots                  3
# 15        15               Sephora tarte birthday gift                  1
# 16        16                         Glitter Eyeshadow                  1
# 17        17       New: Baby K'tan active baby carrier                  1
# 18        18       Too Faced Limited "Merry Macaroons"                  1
# 19        19            Cream/ Beige Front Cross Shirt                  2
# 20        20           Torrid Nautical Peplum Tube Top                  3
# 21        21          NWT VS ULTIMATE SPORTS BRA 34ddd                  1
# 22        22            Galaxy S7 Edge (Unlocked) 32GB                  3
# 23        23                        Triple car charger                  1
# 24        24                Black and Red Baseball Tee                  2
# 25        25                     Air Jordan carmine 6s                  3
# 26        26   Otterbox Defender iPhone 6 Plus/6s Plus                  1
# 27        27    LuLaRoe OS Black With White Polka Dots                  3
# 28        28         Forever21 floral romper strapless                  2
# 29        29                             Kendra bundle                  3
# ..       ...                                       ...                ...
# 70        70                   Adidas Ultraboost Shoes                  3
# 71        71  Partners In Crime Necklace ShipfromChina                  1
# 72        72                    Listing for Aknuckles1                  1
# 73        73                Toddler Vineyard Vines Hat                  3
# 74        74             Rae Dunn Beauty and the Beast                  1
# 75        75     Littlest pet shop accessories for Bon                  3
# 76        76           Black & Burgundy Bikini Bottoms                  1
# 77        77      Aura Fluorite Double Terminated Wand                  1
# 78        78                               Trump Shirt                  3
# 79        79                           Sea wees size 0                  3
# 80        80                      Maternity top bundle                  3
# 81        81     *Hold*FREE TODAY-IT COSMETICS CC HOLD                  1
# 82        82                            Mascara Bundle                  2
# 83        83      Eyebrows Essential Kit MEDIUM; Brown                  1
# 84        84      Women's Espresso Pink Coral shirt XL                  3
# 85        85                         VS PINK sheet Set                  3
# 86        86    Jillian Michaels bodyshred Fitness DVD                  1
# 87        87       Melissa and Doug folding go kitchen                  3
# 88        88        Misty tentacruel foil pokemon card                  3
# 89        89                         Nike boy sneakers                  3
# 90        90                              Jewel holder                  2
# 91        91             Goosebumps HorrorLand DS Game                  3
# 92        92                      Silver jeans size 11                  3
# 93        93              Crimson Tide Alabama T-shirt                  3
# 94        94                        Hatchimals Draggle                  1
# 95        95                 Gap canvas shoes {size 8}                  3
# 96        96       Luminess Air Airbrush Makeup System                  1
# 97        97                 iPhone 5S Mickey ear case                  2
# 98        98                                     Gucci                  3
# 99        99            Size 6 Watercolor Inspire Crop                  3
#
#                                         category_name            brand_name  \
# 0                                   Men/Tops/T-shirts                   NaN
# 1   Electronics/Computers & Tablets/Components & P...                 Razer
# 2                         Women/Tops & Blouses/Blouse                Target
# 3                  Home/Home Décor/Home Décor Accents                   NaN
# 4                             Women/Jewelry/Necklaces                   NaN
# 5                                   Women/Other/Other                   NaN
# 6                            Women/Swimwear/Two-Piece       Acacia Swimwear
# 7                     Sports & Outdoors/Apparel/Girls                 Soffe
# 8                     Sports & Outdoors/Apparel/Girls                  Nike
# 9            Vintage & Collectibles/Collectibles/Doll                   NaN
# 10                                 Beauty/Makeup/Face              Smashbox
# 11                             Beauty/Fragrance/Women     Victoria's Secret
# 12                     Women/Dresses/Above Knee, Mini                   rue
# 13              Other/Office supplies/School Supplies            Scholastic
# 14                                  Women/Shoes/Boots         UGG Australia
# 15                          Beauty/Makeup/Makeup Sets                 Tarte
# 16                                 Beauty/Makeup/Eyes            Wet n Wild
# 17                     Kids/Gear/Backpacks & Carriers                   NaN
# 18                      Beauty/Makeup/Makeup Palettes             Too Faced
# 19                        Women/Tops & Blouses/Blouse         Anthropologie
# 20                    Women/Tops & Blouses/Tank, Cami                Torrid
# 21                 Women/Athletic Apparel/Sports Bras     Victoria's Secret
# 22  Electronics/Cell Phones & Accessories/Cell Pho...               Samsung
# 23  Electronics/Cell Phones & Accessories/Chargers...                   NaN
# 24                      Women/Tops & Blouses/T-Shirts            FOREVER 21
# 25                                 Men/Shoes/Athletic            Air Jordan
# 26  Electronics/Cell Phones & Accessories/Cases, C...                 Apple
# 27     Women/Athletic Apparel/Pants, Tights, Leggings               LuLaRoe
# 28                           Women/Swimwear/One-Piece            FOREVER 21
# 29                               Women/Jeans/Boot Cut             Hollister
# ..                                                ...                   ...
# 70                               Women/Shoes/Athletic                Adidas
# 71                            Women/Jewelry/Necklaces                   NaN
# 72                     Home/Home Décor/Home Fragrance   Nostalgia Electrics
# 73                     Kids/Boys 0-24 Mos/Accessories                   NaN
# 74     Home/Kitchen & Dining/Coffee & Tea Accessories              Rae Dunn
# 75                      Kids/Toys/Dolls & Accessories     Littlest Pet Shop
# 76                           Women/Swimwear/Two-Piece                   NaN
# 77                              Home/Home Décor/Other                   NaN
# 78                                  Men/Tops/T-shirts                   NaN
# 79                          Kids/Girls 0-24 Mos/Shoes              Sea Wees
# 80                     Women/Maternity/Tops & Blouses  Motherhood Maternity
# 81                                 Beauty/Makeup/Face               Sephora
# 82                                 Beauty/Makeup/Eyes                   NaN
# 83                                 Beauty/Makeup/Eyes                   NaN
# 84                      Women/Tops & Blouses/T-Shirts                   NaN
# 85                  Home/Bedding/Sheets & Pillowcases                   NaN
# 86      Sports & Outdoors/Exercise/Fitness technology                   NaN
# 87                  Kids/Toys/Dress Up & Pretend Play        Melissa & Doug
# 88     Vintage & Collectibles/Trading Cards/Animation               Pokemon
# 89                               Kids/Boys (4+)/Shoes                  Nike
# 90  Home/Storage & Organization/Jewelry Boxes & Or...                Target
# 91           Electronics/Video Games & Consoles/Games              Nintendo
# 92                               Women/Jeans/Boot Cut      Silver Jeans Co.
# 93                    Sports & Outdoors/Fan Shop/NCAA                   NaN
# 94                     Kids/Toys/Electronics for Kids           Spin Master
# 95                             Kids/Girls 2T-5T/Shoes                   Gap
# 96                                 Beauty/Makeup/Face                   NaN
# 97  Electronics/Cell Phones & Accessories/Cases, C...                   NaN
# 98                      Men/Men's Accessories/Watches                   NaN
# 99     Women/Athletic Apparel/Pants, Tights, Leggings             Lululemon
#
#     price  shipping                                   item_description
# 0    10.0         1                                 No description yet
# 1    52.0         0  This keyboard is in great condition and works ...
# 2    10.0         1  Adorable top with a hint of lace and a key hol...
# 3    35.0         1  New with tags. Leather horses. Retail for [rm]...
# 4    44.0         0          Complete with certificate of authenticity
# 5    59.0         0  Banana republic bottoms, Candies skirt with ma...
# 6    64.0         0  Size small but straps slightly shortened to fi...
# 7     6.0         1  You get three pairs of Sophie cheer shorts siz...
# 8    19.0         0   Girls Size small Plus green. Three shorts total.
# 9     8.0         0  I realized his pants are on backwards after th...
# 10    8.0         1       0.25 oz Full size is 1oz for [rm] in Sephora
# 11   34.0         0  (5) new vs pink body mists (2.5 oz each) Fresh...
# 12   16.0         0                                Xl, great condition
# 13    4.0         1                                 No description yet
# 14   43.0         0  Authentic. Suede fringe boots. Great condition...
# 15   11.0         1  Brand new. Deluxe travel size products. Contai...
# 16    6.0         1  2 glitter eyeshadows; one in Brass and one in ...
# 17   29.0         1  Brand new in box Size: Medium Color: Coral Ret...
# 18   25.0         1  This AUTHENTIC pallete by Too Faced is brand n...
# 19   27.0         0  Fancy, dressy or casual! Dress it up or down 1...
# 20   13.0         1             Size 1. Worn once. Excellent condition
# 21   20.0         0  NWT Victoria's Secret ULTIMATE SPORT BRA -MAXI...
# 22  386.0         0  Reasonable offers welcomed. But if you ask "lo...
# 23    8.0         1  Brand new never used All colors are available ...
# 24   10.0         0  lanascloset ~~~ description: never worn! ✨ i d...
# 25   66.0         0  They are 100 percent authentic. They are beate...
# 26   13.0         1  Brand new Otterbox Defender iPhone 6 Plus/6s Plus
# 27   24.0         0                 Worn one time. Excellent condition
# 28    5.0         1  Beautiful Excellent condition Zips and ties in...
# 29   16.0         1  29w. X 33l. Social stretch hollister jeans ***...
# ..    ...       ...                                                ...
# 70   61.0         0        Overall good condition. A few signs of wear
# 71    4.0         1  "Fine or Fashion: Fashion Item Type: Necklace ...
# 72   35.0         0  WARMERS PICTURED & 6 SAMPLE PACKAGES OF HIGHLY...
# 73   14.0         0              Probably best for up to a 2 year old.
# 74   26.0         0  Brand new! No cracks or chips! I package every...
# 75   12.0         1                    these are on hold do not buy :)
# 76   17.0         0  Both are a Chinese size medium which fits a US...
# 77   19.0         1  Aura Fluorite: ⋅ The "protection stone" ⋅ Grou...
# 78    9.0         0              Worn once; will be washed before sent
# 79   14.0         0              Great condition sea wees size 0 brown
# 80   16.0         0  Sheer black flowy top with cute flower design....
# 81   14.0         1  New without original Packaging. SHADE IS MEDIU...
# 82    9.0         1      5 Mascaras Loreal Covergirl Rimmel Maybelline
# 83    6.0         1  Eyebrows Essential Kit   Everything you need t...
# 84   10.0         0  Extra large shirt with purple beaded flower de...
# 85   18.0         0  Hot pink/reddish sheet set from Victoria's Sec...
# 86   39.0         0  This boxed set of 12 DVD’s includes the Fitnes...
# 87   34.0         0                  Used but still a great play item.
# 88    3.0         1                                 I have 2 available
# 89   28.0         0  Size 6Y. High tops. Super light. In good condi...
# 90    7.0         1                                 No description yet
# 91   10.0         0   Good used condition. Ask about bundling to save.
# 92   16.0         0  Distressed with holes. Great shape well taken ...
# 93   10.0         0  Size M (8), cuffs show wear and letters are no...
# 94  150.0         1              BNIP VHTF! HOTTEST toy of the season!
# 95    9.0         1  BabyGap canvas army green Gently loved, lots o...
# 96   81.0         1  Bought off Groupon and they charged me for 2, ...
# 97    9.0         1  Bling Mickey ear case!! Just used one for a Di...
# 98   49.0         0  Rose gold bezel and crown Engraved logo Red an...
# 99   44.0         0  Watercolor Inspire crop. No pilling or stickin...
#
# [100 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          6327
# brand_name           632682
# price                     0
# shipping                  0
# item_description          4
# dtype: int64

# %%
df.describe()
# Out:
#            train_id  item_condition_id         price      shipping
# count  1.482535e+06       1.482535e+06  1.482535e+06  1.482535e+06
# mean   7.412670e+05       1.907380e+00  2.673752e+01  4.472744e-01
# std    4.279711e+05       9.031586e-01  3.858607e+01  4.972124e-01
# min    0.000000e+00       1.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.706335e+05       1.000000e+00  1.000000e+01  0.000000e+00
# 50%    7.412670e+05       2.000000e+00  1.700000e+01  0.000000e+00
# 75%    1.111900e+06       3.000000e+00  2.900000e+01  1.000000e+00
# max    1.482534e+06       5.000000e+00  2.009000e+03  1.000000e+00

# %% [markdown]
# <h1>Check test data

# %%
df2=pd.read_csv( 'test.tsv', delimiter='\t' )

# %%
df2.head()
# Out:
#    test_id                                      name  item_condition_id  \
# 0        0  Breast cancer "I fight like a girl" ring                  1
# 1        1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2        2                                 Coach bag                  1
# 3        3                             Floral Kimono                  2
# 4        4                          Life after Death                  3
#
#                                     category_name brand_name  shipping  \
# 0                             Women/Jewelry/Rings        NaN         1
# 1         Other/Office supplies/Shipping Supplies        NaN         1
# 2  Vintage & Collectibles/Bags and Purses/Handbag      Coach         1
# 3                         Women/Sweaters/Cardigan        NaN         0
# 4             Other/Books/Religion & Spirituality        NaN         1
#
#                                     item_description
# 0                                             Size 7
# 1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers Lined...
# 2  Brand new coach bag. Bought for [rm] at a Coac...
# 3  -floral kimono -never worn -lightweight and pe...
# 4  Rediscovering life after the loss of a loved o...

# %% [markdown]
# <h1>Import libraries

# %%
import multiprocessing as mp
import pandas as pd
from time import time
from scipy.sparse import csr_matrix
import os
from sklearn.linear_model import Ridge
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfTransformer
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import gc
from sklearn.base import BaseEstimator, TransformerMixin
import re
from pandas.api.types import is_numeric_dtype, is_categorical_dtype

# %%
os.environ['MKL_NUM_THREADS'] = '4'
os.environ['OMP_NUM_THREADS'] = '4'
os.environ['JOBLIB_START_METHOD'] = 'forkserver'

INPUT_PATH = r''

# %% [markdown]
# <h1>Define functions

# %%
def dameraulevenshtein(seq1, seq2):
    """Calculate the Damerau-Levenshtein distance between sequences.

    This method has not been modified from the original.
    Source: http://mwh.geek.nz/2009/04/26/python-damerau-levenshtein-distance/

    This distance is the number of additions, deletions, substitutions,
    and transpositions needed to transform the first sequence into the
    second. Although generally used with strings, any sequences of
    comparable objects will work.

    Transpositions are exchanges of *consecutive* characters; all other
    operations are self-explanatory.

    This implementation is O(N*M) time and O(M) space, for N and M the
    lengths of the two sequences.

    >>> dameraulevenshtein('ba', 'abc')
    2
    >>> dameraulevenshtein('fee', 'deed')
    2

    It works with arbitrary sequences too:
    >>> dameraulevenshtein('abcd', ['b', 'a', 'c', 'd', 'e'])
    2
    """
    # codesnippet:D0DE4716-B6E6-4161-9219-2903BF8F547F
    # Conceptually, this is based on a len(seq1) + 1 * len(seq2) + 1 matrix.
    # However, only the current and two previous rows are needed at once,
    # so we only store those.
    oneago = None
    thisrow = list(range(1, len(seq2) + 1)) + [0]
    for x in range(len(seq1)):
        # Python lists wrap around for negative indices, so put the
        # leftmost column at the *end* of the list. This matches with
        # the zero-indexed strings and saves extra calculation.
        twoago, oneago, thisrow = (oneago, thisrow, [0] * len(seq2) + [x + 1])
        for y in range(len(seq2)):
            delcost = oneago[y] + 1
            addcost = thisrow[y - 1] + 1
            subcost = oneago[y - 1] + (seq1[x] != seq2[y])
            thisrow[y] = min(delcost, addcost, subcost)
            # This block deals with transpositions
            if (x > 0 and y > 0 and seq1[x] == seq2[y - 1]
                    and seq1[x - 1] == seq2[y] and seq1[x] != seq2[y]):
                thisrow[y] = min(thisrow[y], twoago[y - 2] + 1)
    return thisrow[len(seq2) - 1]

# %% [markdown]
# Sample usage of this function

# %%
dameraulevenshtein('abc','acbd')
# Out:
# 2

# %%
class SymSpell:
    def __init__(self, max_edit_distance=3, verbose=0):
        self.max_edit_distance = max_edit_distance
        self.verbose = verbose
        # 0: top suggestion
        # 1: all suggestions of smallest edit distance
        # 2: all suggestions <= max_edit_distance (slower, no early termination)

        self.dictionary = {}
        self.longest_word_length = 0

    def get_deletes_list(self, w):
        """given a word, derive strings with up to max_edit_distance characters
           deleted"""

        deletes = []
        queue = [w]
        for d in range(self.max_edit_distance):
            temp_queue = []
            for word in queue:
                if len(word) > 1:
                    for c in range(len(word)):  # character index
                        word_minus_c = word[:c] + word[c + 1:]
                        if word_minus_c not in deletes:
                            deletes.append(word_minus_c)
                        if word_minus_c not in temp_queue:
                            temp_queue.append(word_minus_c)
            queue = temp_queue

        return deletes

    def create_dictionary_entry(self, w):
        '''add word and its derived deletions to dictionary'''
        # check if word is already in dictionary
        # dictionary entries are in the form: (list of suggested corrections,
        # frequency of word in corpus)
        new_real_word_added = False
        if w in self.dictionary:
            # increment count of word in corpus
            self.dictionary[w] = (self.dictionary[w][0], self.dictionary[w][1] + 1)
        else:
            self.dictionary[w] = ([], 1)
            self.longest_word_length = max(self.longest_word_length, len(w))

        if self.dictionary[w][1] == 1:
            # first appearance of word in corpus
            # n.b. word may already be in dictionary as a derived word
            # (deleting character from a real word)
            # but counter of frequency of word in corpus is not incremented
            # in those cases)
            new_real_word_added = True
            deletes = self.get_deletes_list(w)
            for item in deletes:
                if item in self.dictionary:
                    # add (correct) word to delete's suggested correction list
                    self.dictionary[item][0].append(w)
                else:
                    # note frequency of word in corpus is not incremented
                    self.dictionary[item] = ([w], 0)

        return new_real_word_added

    def create_dictionary_from_arr(self, arr, token_pattern=r'[a-z]+'):
        total_word_count = 0
        unique_word_count = 0

        for line in arr:
            # separate by words by non-alphabetical characters
            words = re.findall(token_pattern, line.lower())
            for word in words:
                total_word_count += 1
                if self.create_dictionary_entry(word):
                    unique_word_count += 1

        print("total words processed: %i" % total_word_count)
        print("total unique words in corpus: %i" % unique_word_count)
        print("total items in dictionary (corpus words and deletions): %i" % len(self.dictionary))
        print("  edit distance for deletions: %i" % self.max_edit_distance)
        print("  length of longest word in corpus: %i" % self.longest_word_length)
        return self.dictionary

    def create_dictionary(self, fname):
        total_word_count = 0
        unique_word_count = 0

        with open(fname) as file:
            for line in file:
                # separate by words by non-alphabetical characters
                words = re.findall('[a-z]+', line.lower())
                for word in words:
                    total_word_count += 1
                    if self.create_dictionary_entry(word):
                        unique_word_count += 1

        print("total words processed: %i" % total_word_count)
        print("total unique words in corpus: %i" % unique_word_count)
        print("total items in dictionary (corpus words and deletions): %i" % len(self.dictionary))
        print("  edit distance for deletions: %i" % self.max_edit_distance)
        print("  length of longest word in corpus: %i" % self.longest_word_length)
        return self.dictionary

    def get_suggestions(self, string, silent=False):
        """return list of suggested corrections for potentially incorrectly
           spelled word"""
        if (len(string) - self.longest_word_length) > self.max_edit_distance:
            if not silent:
                print("no items in dictionary within maximum edit distance")
            return []

        suggest_dict = {}
        min_suggest_len = float('inf')

        queue = [string]
        q_dictionary = {}  # items other than string that we've checked

        while len(queue) > 0:
            q_item = queue[0]  # pop
            queue = queue[1:]

            # early exit
            if ((self.verbose < 2) and (len(suggest_dict) > 0) and
                    ((len(string) - len(q_item)) > min_suggest_len)):
                break

            # process queue item
            if (q_item in self.dictionary) and (q_item not in suggest_dict):
                if self.dictionary[q_item][1] > 0:
                    # word is in dictionary, and is a word from the corpus, and
                    # not already in suggestion list so add to suggestion
                    # dictionary, indexed by the word with value (frequency in
                    # corpus, edit distance)
                    # note q_items that are not the input string are shorter
                    # than input string since only deletes are added (unless
                    # manual dictionary corrections are added)
                    assert len(string) >= len(q_item)
                    suggest_dict[q_item] = (self.dictionary[q_item][1],
                                            len(string) - len(q_item))
                    # early exit
                    if (self.verbose < 2) and (len(string) == len(q_item)):
                        break
                    elif (len(string) - len(q_item)) < min_suggest_len:
                        min_suggest_len = len(string) - len(q_item)

                # the suggested corrections for q_item as stored in
                # dictionary (whether or not q_item itself is a valid word
                # or merely a delete) can be valid corrections
                for sc_item in self.dictionary[q_item][0]:
                    if sc_item not in suggest_dict:

                        # compute edit distance
                        # suggested items should always be longer
                        # (unless manual corrections are added)
                        assert len(sc_item) > len(q_item)

                        # q_items that are not input should be shorter
                        # than original string
                        # (unless manual corrections added)
                        assert len(q_item) <= len(string)

                        if len(q_item) == len(string):
                            assert q_item == string
                            item_dist = len(sc_item) - len(q_item)

                        # item in suggestions list should not be the same as
                        # the string itself
                        assert sc_item != string

                        # calculate edit distance using, for example,
                        # Damerau-Levenshtein distance
                        item_dist = dameraulevenshtein(sc_item, string)

                        # do not add words with greater edit distance if
                        # verbose setting not on
                        if (self.verbose < 2) and (item_dist > min_suggest_len):
                            pass
                        elif item_dist <= self.max_edit_distance:
                            assert sc_item in self.dictionary  # should already be in dictionary if in suggestion list
                            suggest_dict[sc_item] = (self.dictionary[sc_item][1], item_dist)
                            if item_dist < min_suggest_len:
                                min_suggest_len = item_dist

                        # depending on order words are processed, some words
                        # with different edit distances may be entered into
                        # suggestions; trim suggestion dictionary if verbose
                        # setting not on
                        if self.verbose < 2:
                            suggest_dict = {k: v for k, v in suggest_dict.items() if v[1] <= min_suggest_len}

            # now generate deletes (e.g. a substring of string or of a delete)
            # from the queue item
            # as additional items to check -- add to end of queue
            assert len(string) >= len(q_item)

            # do not add words with greater edit distance if verbose setting
            # is not on
            if (self.verbose < 2) and ((len(string) - len(q_item)) > min_suggest_len):
                pass
            elif (len(string) - len(q_item)) < self.max_edit_distance and len(q_item) > 1:
                for c in range(len(q_item)):  # character index
                    word_minus_c = q_item[:c] + q_item[c + 1:]
                    if word_minus_c not in q_dictionary:
                        queue.append(word_minus_c)
                        q_dictionary[word_minus_c] = None  # arbitrary value, just to identify we checked this

        # queue is now empty: convert suggestions in dictionary to
        # list for output
        if not silent and self.verbose != 0:
            print("number of possible corrections: %i" % len(suggest_dict))
            print("  edit distance for deletions: %i" % self.max_edit_distance)

        # output option 1
        # sort results by ascending order of edit distance and descending
        # order of frequency
        #     and return list of suggested word corrections only:
        # return sorted(suggest_dict, key = lambda x:
        #               (suggest_dict[x][1], -suggest_dict[x][0]))

        # output option 2
        # return list of suggestions with (correction,
        #                                  (frequency in corpus, edit distance)):
        as_list = suggest_dict.items()
        # outlist = sorted(as_list, key=lambda (term, (freq, dist)): (dist, -freq))
        outlist = sorted(as_list, key=lambda x: (x[1][1], -x[1][0]))

        if self.verbose == 0:
            return outlist[0]
        else:
            return outlist

        '''
        Option 1:
        ['file', 'five', 'fire', 'fine', ...]

        Option 2:
        [('file', (5, 0)),
         ('five', (67, 1)),
         ('fire', (54, 1)),
         ('fine', (17, 1))...]  
        '''

    def best_word(self, s, silent=False):
        try:
            return self.get_suggestions(s, silent)[0]
        except:
            return None

# %%
class ItemSelector(BaseEstimator, TransformerMixin):
    def __init__(self, field, start_time=time()):
        self.field = field
        self.start_time = start_time

    def fit(self, x, y=None):
        return self

    def transform(self, dataframe):
        print(f'[{time()-self.start_time}] select {self.field}')
        dt = dataframe[self.field].dtype
        if is_categorical_dtype(dt):
            return dataframe[self.field].cat.codes[:, None]
        elif is_numeric_dtype(dt):
            return dataframe[self.field][:, None]
        else:
            return dataframe[self.field]

# %%
class DropColumnsByDf(BaseEstimator, TransformerMixin):
    def __init__(self, min_df=1, max_df=1.0):
        self.min_df = min_df
        self.max_df = max_df

    def fit(self, X, y=None):
        m = X.tocsc()
        self.nnz_cols = ((m != 0).sum(axis=0) >= self.min_df).A1
        if self.max_df < 1.0:
            max_df = m.shape[0] * self.max_df
            self.nnz_cols = self.nnz_cols & ((m != 0).sum(axis=0) <= max_df).A1
        return self

    def transform(self, X, y=None):
        m = X.tocsc()
        return m[:, self.nnz_cols]

# %%
def get_rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(np.expm1(y_true), np.expm1(y_pred)))

# %%
def split_cat(text):
    try:
        cats = text.split("/")
        return cats[0], cats[1], cats[2], cats[0] + '/' + cats[1]
    except:
        print("no category")
        return 'other', 'other', 'other', 'other/other'

# %%
def brands_filling(dataset):
    vc = dataset['brand_name'].value_counts()
    brands = vc[vc > 0].index
    brand_word = r"[a-z0-9*/+\-'’?!.,|&%®™ôèéü]+"

    many_w_brands = brands[brands.str.contains(' ')]
    one_w_brands = brands[~brands.str.contains(' ')]

    ss2 = SymSpell(max_edit_distance=0)
    ss2.create_dictionary_from_arr(many_w_brands, token_pattern=r'.+')

    ss1 = SymSpell(max_edit_distance=0)
    ss1.create_dictionary_from_arr(one_w_brands, token_pattern=r'.+')

    two_words_re = re.compile(r"(?=(\s[a-z0-9*/+\-'’?!.,|&%®™ôèéü]+\s[a-z0-9*/+\-'’?!.,|&%®™ôèéü]+))")

    def find_in_str_ss2(row):
        for doc_word in two_words_re.finditer(row):
            print(doc_word)
            suggestion = ss2.best_word(doc_word.group(1), silent=True)
            if suggestion is not None:
                return doc_word.group(1)
        return ''

    def find_in_list_ss1(list):
        for doc_word in list:
            suggestion = ss1.best_word(doc_word, silent=True)
            if suggestion is not None:
                return doc_word
        return ''

    def find_in_list_ss2(list):
        for doc_word in list:
            suggestion = ss2.best_word(doc_word, silent=True)
            if suggestion is not None:
                return doc_word
        return ''

    print(f"Before empty brand_name: {len(dataset[dataset['brand_name'] == ''].index)}")

    n_name = dataset[dataset['brand_name'] == '']['name'].str.findall(
        pat=r"^[a-z0-9*/+\-'’?!.,|&%®™ôèéü]+\s[a-z0-9*/+\-'’?!.,|&%®™ôèéü]+")
    dataset.loc[dataset['brand_name'] == '', 'brand_name'] = [find_in_list_ss2(row) for row in n_name]

    n_desc = dataset[dataset['brand_name'] == '']['item_description'].str.findall(
        pat=r"^[a-z0-9*/+\-'’?!.,|&%®™ôèéü]+\s[a-z0-9*/+\-'’?!.,|&%®™ôèéü]+")
    dataset.loc[dataset['brand_name'] == '', 'brand_name'] = [find_in_list_ss2(row) for row in n_desc]

    n_name = dataset[dataset['brand_name'] == '']['name'].str.findall(pat=brand_word)
    dataset.loc[dataset['brand_name'] == '', 'brand_name'] = [find_in_list_ss1(row) for row in n_name]

    desc_lower = dataset[dataset['brand_name'] == '']['item_description'].str.findall(pat=brand_word)
    dataset.loc[dataset['brand_name'] == '', 'brand_name'] = [find_in_list_ss1(row) for row in desc_lower]

    print(f"After empty brand_name: {len(dataset[dataset['brand_name'] == ''].index)}")

    del ss1, ss2
    gc.collect()

# %%
def preprocess_regex(dataset, start_time=time()):
    karats_regex = r'(\d)([\s-]?)(karat|karats|carat|carats|kt)([^\w])'
    karats_repl = r'\1k\4'

    unit_regex = r'(\d+)[\s-]([a-z]{2})(\s)'
    unit_repl = r'\1\2\3'

    dataset['name'] = dataset['name'].str.replace(karats_regex, karats_repl)
    dataset['item_description'] = dataset['item_description'].str.replace(karats_regex, karats_repl)
    print(f'[{time() - start_time}] Karats normalized.')

    dataset['name'] = dataset['name'].str.replace(unit_regex, unit_repl)
    dataset['item_description'] = dataset['item_description'].str.replace(unit_regex, unit_repl)
    print(f'[{time() - start_time}] Units glued.')

# %%
def preprocess_pandas(train, test, start_time=time()):
    train = train[train.price > 0.0].reset_index(drop=True)
    print('Train shape without zero price: ', train.shape)

    nrow_train = train.shape[0]
    y_train = np.log1p(train["price"])
    merge: pd.DataFrame = pd.concat([train, test])

    del train
    del test
    gc.collect()

    merge['has_category'] = (merge['category_name'].notnull()).astype('category')
    print(f'[{time() - start_time}] Has_category filled.')

    merge['category_name'] = merge['category_name'] \
        .fillna('other/other/other') \
        .str.lower() \
        .astype(str)
    merge['general_cat'], merge['subcat_1'], merge['subcat_2'], merge['gen_subcat1'] = \
        zip(*merge['category_name'].apply(lambda x: split_cat(x)))
    print(f'[{time() - start_time}] Split categories completed.')

    merge['has_brand'] = (merge['brand_name'].notnull()).astype('category')
    print(f'[{time() - start_time}] Has_brand filled.')

    merge['gencat_cond'] = merge['general_cat'].map(str) + '_' + merge['item_condition_id'].astype(str)
    merge['subcat_1_cond'] = merge['subcat_1'].map(str) + '_' + merge['item_condition_id'].astype(str)
    merge['subcat_2_cond'] = merge['subcat_2'].map(str) + '_' + merge['item_condition_id'].astype(str)
    print(f'[{time() - start_time}] Categories and item_condition_id concancenated.')

    merge['name'] = merge['name'] \
        .fillna('') \
        .str.lower() \
        .astype(str)
    merge['brand_name'] = merge['brand_name'] \
        .fillna('') \
        .str.lower() \
        .astype(str)
    merge['item_description'] = merge['item_description'] \
        .fillna('') \
        .str.lower() \
        .replace(to_replace='No description yet', value='')
    print(f'[{time() - start_time}] Missing filled.')

    preprocess_regex(merge, start_time)

    brands_filling(merge)
    print(f'[{time() - start_time}] Brand name filled.')

    merge['name'] = merge['name'] + ' ' + merge['brand_name']
    print(f'[{time() - start_time}] Name concancenated.')

    merge['item_description'] = merge['item_description'] \
                                + ' ' + merge['name'] \
                                + ' ' + merge['subcat_1'] \
                                + ' ' + merge['subcat_2'] \
                                + ' ' + merge['general_cat'] \
                                + ' ' + merge['brand_name']
    print(f'[{time() - start_time}] Item description concatenated.')

    merge.drop(['price', 'test_id', 'train_id'], axis=1, inplace=True)

    return merge, y_train, nrow_train

# %%
def intersect_drop_columns(train: csr_matrix, valid: csr_matrix, min_df=0):
    t = train.tocsc()
    v = valid.tocsc()
    nnz_train = ((t != 0).sum(axis=0) >= min_df).A1
    nnz_valid = ((v != 0).sum(axis=0) >= min_df).A1
    nnz_cols = nnz_train & nnz_valid
    res = t[:, nnz_cols], v[:, nnz_cols]
    return res

# %%
mp.set_start_method('forkserver', True)

# %%
start_time = time()

# %% [markdown]
# Read training data

# %%
train = pd.read_table(os.path.join(INPUT_PATH, 'train.tsv'),
                          engine='c',
                          dtype={'item_condition_id': 'category',
                                 'shipping': 'category'}
                          )

# %%
train.head()
# Out:
#    train_id                                 name item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                 3
# 1         1     Razer BlackWidow Chroma Keyboard                 3
# 2         2                       AVA-VIV Blouse                 1
# 3         3                Leather Horse Statues                 1
# 4         4                 24K GOLD plated rose                 1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#   shipping                                   item_description
# 0        1                                 No description yet
# 1        0  This keyboard is in great condition and works ...
# 2        1  Adorable top with a hint of lace and a key hol...
# 3        1  New with tags. Leather horses. Retail for [rm]...
# 4        0          Complete with certificate of authenticity

# %%
train.describe()
# Out:
#            train_id         price
# count  1.482535e+06  1.482535e+06
# mean   7.412670e+05  2.673752e+01
# std    4.279711e+05  3.858607e+01
# min    0.000000e+00  0.000000e+00
# 25%    3.706335e+05  1.000000e+01
# 50%    7.412670e+05  1.700000e+01
# 75%    1.111900e+06  2.900000e+01
# max    1.482534e+06  2.009000e+03

# %% [markdown]
# Read test data

# %%
test = pd.read_table(os.path.join(INPUT_PATH, 'test.tsv'),
                         engine='c',
                         dtype={'item_condition_id': 'category',
                                'shipping': 'category'}
                         )

# %%
print(f'[{time() - start_time}] Finished to load data')
print('Train shape: ', train.shape)
print('Test shape: ', test.shape)
# Out:
# [15.079428672790527] Finished to load data
# Train shape:  (1482535, 8)
# Test shape:  (693359, 7)

# %%
submission: pd.DataFrame = test[['test_id']]

# %% [markdown]
# <h1>Preprocessing

# %% [markdown]
# ここからpreprocess_pandas関数の中身

# %%
train = train[train.price > 0.0].reset_index(drop=True)

# %%
train.describe()
# Out:
#            train_id         price
# count  1.481661e+06  1.481661e+06
# mean   7.412437e+05  2.675329e+01
# std    4.279715e+05  3.859198e+01
# min    0.000000e+00  3.000000e+00
# 25%    3.705880e+05  1.000000e+01
# 50%    7.412380e+05  1.700000e+01
# 75%    1.111877e+06  2.900000e+01
# max    1.482534e+06  2.009000e+03

# %%
print('Train shape without zero price: ', train.shape)
# Out:
# Train shape without zero price:  (1481661, 8)

# %%
nrow_train = train.shape[0]
y_train = np.log1p(train["price"])
merge: pd.DataFrame = pd.concat([train, test])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
merge.head()
# Out:
#   brand_name                                      category_name  \
# 0        NaN                                  Men/Tops/T-shirts
# 1      Razer  Electronics/Computers & Tablets/Components & P...
# 2     Target                        Women/Tops & Blouses/Blouse
# 3        NaN                 Home/Home Décor/Home Décor Accents
# 4        NaN                            Women/Jewelry/Necklaces
#
#   item_condition_id                                   item_description  \
# 0                 3                                 No description yet
# 1                 3  This keyboard is in great condition and works ...
# 2                 1  Adorable top with a hint of lace and a key hol...
# 3                 1  New with tags. Leather horses. Retail for [rm]...
# 4                 1          Complete with certificate of authenticity
#
#                                   name  price shipping  test_id  train_id
# 0  MLB Cincinnati Reds T Shirt Size XL   10.0        1      NaN       0.0
# 1     Razer BlackWidow Chroma Keyboard   52.0        0      NaN       1.0
# 2                       AVA-VIV Blouse   10.0        1      NaN       2.0
# 3                Leather Horse Statues   35.0        1      NaN       3.0
# 4                 24K GOLD plated rose   44.0        0      NaN       4.0

# %%
del train
del test
gc.collect()
# Out:
# 287

# %%
merge['has_category'] = (merge['category_name'].notnull()).astype('category')
print(f'[{time() - start_time}] Has_category filled.')
# Out:
# [17.61883854866028] Has_category filled.

# %%
merge.shape
# Out:
# (2175020, 10)

# %%
merge['category_name'] = merge['category_name'] \
        .fillna('other/other/other') \
        .str.lower() \
        .astype(str)

# %%
merge['general_cat'], merge['subcat_1'], merge['subcat_2'], merge['gen_subcat1'] = \
        zip(*merge['category_name'].apply(lambda x: split_cat(x)))

# %%
print(f'[{time() - start_time}] Split categories completed.')
# Out:
# [40.00105047225952] Split categories completed.

# %%
merge['has_brand'] = (merge['brand_name'].notnull()).astype('category')
print(f'[{time() - start_time}] Has_brand filled.')
# Out:
# [40.326908826828] Has_brand filled.

# %%
merge['gencat_cond'] = merge['general_cat'].map(str) + '_' + merge['item_condition_id'].astype(str)
merge['subcat_1_cond'] = merge['subcat_1'].map(str) + '_' + merge['item_condition_id'].astype(str)
merge['subcat_2_cond'] = merge['subcat_2'].map(str) + '_' + merge['item_condition_id'].astype(str)
print(f'[{time() - start_time}] Categories and item_condition_id concancenated.')
# Out:
# [48.738794565200806] Categories and item_condition_id concancenated.

# %%
merge['name'] = merge['name'] \
        .fillna('') \
        .str.lower() \
        .astype(str)
merge['brand_name'] = merge['brand_name'] \
        .fillna('') \
        .str.lower() \
        .astype(str)
merge['item_description'] = merge['item_description'] \
        .fillna('') \
        .str.lower() \
        .replace(to_replace='No description yet', value='')
print(f'[{time() - start_time}] Missing filled.')
# Out:
# [59.019036293029785] Missing filled.

# %%
merge.head()
# Out:
#   brand_name                                      category_name  \
# 0                                             men/tops/t-shirts
# 1      razer  electronics/computers & tablets/components & p...
# 2     target                        women/tops & blouses/blouse
# 3                            home/home décor/home décor accents
# 4                                       women/jewelry/necklaces
#
#   item_condition_id                                   item_description  \
# 0                 3                                 no description yet
# 1                 3  this keyboard is in great condition and works ...
# 2                 1  adorable top with a hint of lace and a key hol...
# 3                 1  new with tags. leather horses. retail for [rm]...
# 4                 1          complete with certificate of authenticity
#
#                                   name  price shipping  test_id  train_id  \
# 0  mlb cincinnati reds t shirt size xl   10.0        1      NaN       0.0
# 1     razer blackwidow chroma keyboard   52.0        0      NaN       1.0
# 2                       ava-viv blouse   10.0        1      NaN       2.0
# 3                leather horse statues   35.0        1      NaN       3.0
# 4                 24k gold plated rose   44.0        0      NaN       4.0
#
#   has_category  general_cat             subcat_1            subcat_2  \
# 0         True          men                 tops            t-shirts
# 1         True  electronics  computers & tablets  components & parts
# 2         True        women       tops & blouses              blouse
# 3         True         home           home décor  home décor accents
# 4         True        women              jewelry           necklaces
#
#                        gen_subcat1 has_brand    gencat_cond  \
# 0                         men/tops     False          men_3
# 1  electronics/computers & tablets      True  electronics_3
# 2             women/tops & blouses      True        women_1
# 3                  home/home décor     False         home_1
# 4                    women/jewelry     False        women_1
#
#            subcat_1_cond         subcat_2_cond
# 0                 tops_3            t-shirts_3
# 1  computers & tablets_3  components & parts_3
# 2       tops & blouses_1              blouse_1
# 3           home décor_1  home décor accents_1
# 4              jewelry_1           necklaces_1

# %%
preprocess_regex(merge, start_time)
# Out:
# [80.49422407150269] Karats normalized.
# [104.58873200416565] Units glued.

# %%
brands_filling(merge)
print(f'[{time() - start_time}] Brand name filled.')
# Out:
# total words processed: 2671
# total unique words in corpus: 2671
# total items in dictionary (corpus words and deletions): 2671
#   edit distance for deletions: 0
#   length of longest word in corpus: 39
# total words processed: 2616
# total unique words in corpus: 2616
# total items in dictionary (corpus words and deletions): 2616
#   edit distance for deletions: 0
#   length of longest word in corpus: 15
# Before empty brand_name: 927861
# After empty brand_name: 252719
# [190.3572380542755] Brand name filled.

# %%
merge
# Out:
#                brand_name                                      category_name  \
# 0                     mlb                                  men/tops/t-shirts
# 1                   razer  electronics/computers & tablets/components & p...
# 2                  target                        women/tops & blouses/blouse
# 3                                         home/home décor/home décor accents
# 4                complete                            women/jewelry/necklaces
# 5         banana republic                                  women/other/other
# 6         acacia swimwear                           women/swimwear/two-piece
# 7                   soffe                    sports & outdoors/apparel/girls
# 8                    nike                    sports & outdoors/apparel/girls
# 9                      so           vintage & collectibles/collectibles/doll
# 10               smashbox                                 beauty/makeup/face
# 11      victoria's secret                             beauty/fragrance/women
# 12                    rue                     women/dresses/above knee, mini
# 13             scholastic              other/office supplies/school supplies
# 14          ugg australia                                  women/shoes/boots
# 15                  tarte                          beauty/makeup/makeup sets
# 16             wet n wild                                 beauty/makeup/eyes
# 17                 active                     kids/gear/backpacks & carriers
# 18              too faced                      beauty/makeup/makeup palettes
# 19          anthropologie                        women/tops & blouses/blouse
# 20                 torrid                    women/tops & blouses/tank, cami
# 21      victoria's secret                 women/athletic apparel/sports bras
# 22                samsung  electronics/cell phones & accessories/cell pho...
# 23                    all  electronics/cell phones & accessories/chargers...
# 24             forever 21                      women/tops & blouses/t-shirts
# 25             air jordan                                 men/shoes/athletic
# 26                  apple  electronics/cell phones & accessories/cases, c...
# 27                lularoe     women/athletic apparel/pants, tights, leggings
# 28             forever 21                           women/swimwear/one-piece
# 29              hollister                               women/jeans/boot cut
# ...                   ...                                                ...
# 693329     mcfarlane toys                 kids/toys/action figures & statues
# 693330               nike                              women/sweaters/hooded
# 693331                                     kids/diapering/disposable diapers
# 693332              coach               women/women's accessories/sunglasses
# 693333                                        women/athletic apparel/jackets
# 693334         tory burch                                  women/shoes/pumps
# 693335                                    vintage & collectibles/serving/mug
# 693336                and                 home/home décor/home décor accents
# 693337                gap                 kids/boys 0-24 mos/tops & t-shirts
# 693338  victoria's secret                               women/underwear/bras
# 693339                all                            beauty/bath & body/bath
# 693340                     beauty/tools & accessories/makeup brushes & tools
# 693341              apple  electronics/computers & tablets/laptops & netb...
# 693342             silver                             women/jewelry/earrings
# 693343        bobbi brown                                 beauty/makeup/face
# 693344            kiehl's                              beauty/skin care/face
# 693345             disney                  kids/toys/stuffed animals & plush
# 693346             adidas                       women/shoes/fashion sneakers
# 693347       calvin klein                                  women/shoes/boots
# 693348               pink         women/athletic apparel/tracksuits & sweats
# 693349                nyx                                 beauty/makeup/lips
# 693350                and                                    kids/toys/games
# 693351           old navy                      kids/boys (4+)/top & t-shirts
# 693352            express                            women/sweaters/cardigan
# 693353        urban decay                                 beauty/makeup/face
# 693354                and                 home/home décor/home décor accents
# 693355       it cosmetics                          beauty/makeup/makeup sets
# 693356             galaxy  electronics/cell phones & accessories/cases, c...
# 693357                                              women/swimwear/cover-ups
# 693358                                         women/tops & blouses/t-shirts
#
#        item_condition_id                                   item_description  \
# 0                      3                                 no description yet
# 1                      3  this keyboard is in great condition and works ...
# 2                      1  adorable top with a hint of lace and a key hol...
# 3                      1  new with tags. leather horses. retail for [rm]...
# 4                      1          complete with certificate of authenticity
# 5                      3  banana republic bottoms, candies skirt with ma...
# 6                      3  size small but straps slightly shortened to fi...
# 7                      3  you get three pairs of sophie cheer shorts siz...
# 8                      3   girls size small plus green. three shorts total.
# 9                      3  i realized his pants are on backwards after th...
# 10                     2        0.25oz full size is 1oz for [rm] in sephora
# 11                     1  (5) new vs pink body mists (2.5oz each) fresh ...
# 12                     2                                xl, great condition
# 13                     1                                 no description yet
# 14                     3  authentic. suede fringe boots. great condition...
# 15                     1  brand new. deluxe travel size products. contai...
# 16                     1  2 glitter eyeshadows; one in brass and one in ...
# 17                     1  brand new in box size: medium color: coral ret...
# 18                     1  this authentic pallete by too faced is brand n...
# 19                     2  fancy, dressy or casual! dress it up or down 1...
# 20                     3             size 1. worn once. excellent condition
# 21                     1  nwt victoria's secret ultimate sport bra -maxi...
# 22                     3  reasonable offers welcomed. but if you ask "lo...
# 23                     1  brand new never used all colors are available ...
# 24                     2  lanascloset ~~~ description: never worn! ✨ i d...
# 25                     3  they are 100 percent authentic. they are beate...
# 26                     1  brand new otterbox defender iphone 6 plus/6s plus
# 27                     3                 worn one time. excellent condition
# 28                     2  beautiful excellent condition zips and ties in...
# 29                     3  29w. x 33l. social stretch hollister jeans ***...
# ...                  ...                                                ...
# 693329                 3      5 action figures halo mcfarlane no accesories
# 693330                 2  hi this is a large woman's therma-fit pullover...
# 693331                 2                                           like new
# 693332                 2  nwot coach delphine tortoise shell sunglasses,...
# 693333                 3          imitation leather white in good condition
# 693334                 3  rare authentic size 6.5 tory burch wedges. sho...
# 693335                 5                                 no description yet
# 693336                 1  100% organic & it really works! incredible for...
# 693337                 3  last chance before they go to consignment! var...
# 693338                 3                                           size 34b
# 693339                 1  from their beetlejuice collection! collection ...
# 693340                 1  free shipping eyecat smokey eyeliner stencil tool
# 693341                 4  macbook 13" i7 2011 this laptop is in working ...
# 693342                 1  please follow me for new listings. this site n...
# 693343                 3  this is a stay all day, lightweight foundation...
# 693344                 1  brand new in box kiehl's midnight recovery con...
# 693345                 3  disney store exclusive marie about 10 inches l...
# 693346                 3  adidas tubular invader strap size 9in women us...
# 693347                 1  size 8 i'm a 8.5 and they fit me worn once for...
# 693348                 1  large strappy leggings and large bling campus ...
# 693349                 1  ❗️listing is for 1❗️ brand new shades piu05 sc...
# 693350                 1    [rm] free shipping too new and highly addictive
# 693351                 1  purple boys polo shirt in size 10/12. old navy...
# 693352                 3  express deep olive green cardigan | ultra thin...
# 693353                 3          in the shade medium neutral. barley used.
# 693354                 1  flint/quartz cluster. self mined ✨measures 3x2...
# 693355                 1  it cosmetics travel bundle. includes: brow pow...
# 693356                 1                    new. free shipping basstop case
# 693357                 2  floral kimono. tropical print. open front. hi ...
# 693358                 2  2 floral scrub tops. worn less than 5 times ea...
#
#                                            name  price shipping   test_id  \
# 0           mlb cincinnati reds t shirt size xl   10.0        1       NaN
# 1              razer blackwidow chroma keyboard   52.0        0       NaN
# 2                                ava-viv blouse   10.0        1       NaN
# 3                         leather horse statues   35.0        1       NaN
# 4                          24k gold plated rose   44.0        0       NaN
# 5              bundled items requested for ruie   59.0        0       NaN
# 6            acacia pacific tides santorini top   64.0        0       NaN
# 7          girls cheer and tumbling bundle of 7    6.0        1       NaN
# 8                         girls nike pro shorts   19.0        0       NaN
# 9        porcelain clown doll checker pants vtg    8.0        0       NaN
# 10                              smashbox primer    8.0        1       NaN
# 11                       new vs pi k body mists   34.0        0       NaN
# 12                           black skater dress   16.0        0       NaN
# 13                         sharpener and eraser    4.0        1       NaN
# 14           hold for dogs2016 minnetonka boots   43.0        0       NaN
# 15                  sephora tarte birthday gift   11.0        1       NaN
# 16                            glitter eyeshadow    6.0        1       NaN
# 17          new: baby k'tan active baby carrier   29.0        1       NaN
# 18          too faced limited "merry macaroons"   25.0        1       NaN
# 19               cream/ beige front cross shirt   27.0        0       NaN
# 20              torrid nautical peplum tube top   13.0        1       NaN
# 21             nwt vs ultimate sports bra 34ddd   20.0        0       NaN
# 22               galaxy s7 edge (unlocked) 32gb  386.0        0       NaN
# 23                           triple car charger    8.0        1       NaN
# 24                   black and red baseball tee   10.0        0       NaN
# 25                        air jordan carmine 6s   66.0        0       NaN
# 26      otterbox defender iphone 6 plus/6s plus   13.0        1       NaN
# 27       lularoe os black with white polka dots   24.0        0       NaN
# 28            forever21 floral romper strapless    5.0        1       NaN
# 29                                kendra bundle   16.0        1       NaN
# ...                                         ...    ...      ...       ...
# 693329          lot 5 acción figures macfarlane    NaN        0  693329.0
# 693330                 nike hoodie just do it l    NaN        1  693330.0
# 693331           23 unisex diapers size newborn    NaN        0  693331.0
# 693332  nwot coach "delphine" sunglasses w/case    NaN        1  693332.0
# 693333                    womems leather jacket    NaN        0  693333.0
# 693334                    tory burch 6.5 wedges    NaN        0  693334.0
# 693335                                 hi-c mug    NaN        0  693335.0
# 693336   removes coffee stains & yellow teeth!!    NaN        1  693336.0
# 693337      must go! lot of toddler boy clothes    NaN        0  693337.0
# 693338                                   vs bra    NaN        0  693338.0
# 693339                      fortune cookie soap    NaN        0  693339.0
# 693340  2pcs eyecat smokey eyeliner stencil set    NaN        1  693340.0
# 693341                          macbook pro 13"    NaN        0  693341.0
# 693342     sterling silver triangle cz earrings    NaN        1  693342.0
# 693343       bobbi brown warm ivory foundation.    NaN        0  693343.0
# 693344    kiehl's midnight recovery concentrate    NaN        0  693344.0
# 693345                       disney store marie    NaN        0  693345.0
# 693346             adidas tubular invader strap    NaN        1  693346.0
# 693347          calvin klein booties heel boots    NaN        0  693347.0
# 693348                            bundle add on    NaN        1  693348.0
# 693349                          nyx lip plumper    NaN        1  693349.0
# 693350    new fidget hand spinner desk toy cube    NaN        1  693350.0
# 693351           boys polo shirt in size 10/12.    NaN        0  693351.0
# 693352        express deep olive green cardigan    NaN        1  693352.0
# 693353                  urban decay face powder    NaN        1  693353.0
# 693354            quartz crystal on flint stone    NaN        0  693354.0
# 693355             it cosmetics - travel bundle    NaN        1  693355.0
# 693356                galaxy s8 hard shell case    NaN        1  693356.0
# 693357                     hi low floral kimono    NaN        0  693357.0
# 693358    freeship 2 floral scrub tops, medium.    NaN        1  693358.0
#
#         train_id has_category             general_cat  \
# 0            0.0         True                     men
# 1            1.0         True             electronics
# 2            2.0         True                   women
# 3            3.0         True                    home
# 4            4.0         True                   women
# 5            5.0         True                   women
# 6            6.0         True                   women
# 7            7.0         True       sports & outdoors
# 8            8.0         True       sports & outdoors
# 9            9.0         True  vintage & collectibles
# 10          10.0         True                  beauty
# 11          11.0         True                  beauty
# 12          12.0         True                   women
# 13          13.0         True                   other
# 14          14.0         True                   women
# 15          15.0         True                  beauty
# 16          16.0         True                  beauty
# 17          17.0         True                    kids
# 18          18.0         True                  beauty
# 19          19.0         True                   women
# 20          20.0         True                   women
# 21          21.0         True                   women
# 22          22.0         True             electronics
# 23          23.0         True             electronics
# 24          24.0         True                   women
# 25          25.0         True                     men
# 26          26.0         True             electronics
# 27          27.0         True                   women
# 28          28.0         True                   women
# 29          29.0         True                   women
# ...          ...          ...                     ...
# 693329       NaN         True                    kids
# 693330       NaN         True                   women
# 693331       NaN         True                    kids
# 693332       NaN         True                   women
# 693333       NaN         True                   women
# 693334       NaN         True                   women
# 693335       NaN         True  vintage & collectibles
# 693336       NaN         True                    home
# 693337       NaN         True                    kids
# 693338       NaN         True                   women
# 693339       NaN         True                  beauty
# 693340       NaN         True                  beauty
# 693341       NaN         True             electronics
# 693342       NaN         True                   women
# 693343       NaN         True                  beauty
# 693344       NaN         True                  beauty
# 693345       NaN         True                    kids
# 693346       NaN         True                   women
# 693347       NaN         True                   women
# 693348       NaN         True                   women
# 693349       NaN         True                  beauty
# 693350       NaN         True                    kids
# 693351       NaN         True                    kids
# 693352       NaN         True                   women
# 693353       NaN         True                  beauty
# 693354       NaN         True                    home
# 693355       NaN         True                  beauty
# 693356       NaN         True             electronics
# 693357       NaN         True                   women
# 693358       NaN         True                   women
#
#                          subcat_1                   subcat_2  \
# 0                            tops                   t-shirts
# 1             computers & tablets         components & parts
# 2                  tops & blouses                     blouse
# 3                      home décor         home décor accents
# 4                         jewelry                  necklaces
# 5                           other                      other
# 6                        swimwear                  two-piece
# 7                         apparel                      girls
# 8                         apparel                      girls
# 9                    collectibles                       doll
# 10                         makeup                       face
# 11                      fragrance                      women
# 12                        dresses           above knee, mini
# 13                office supplies            school supplies
# 14                          shoes                      boots
# 15                         makeup                makeup sets
# 16                         makeup                       eyes
# 17                           gear       backpacks & carriers
# 18                         makeup            makeup palettes
# 19                 tops & blouses                     blouse
# 20                 tops & blouses                 tank, cami
# 21               athletic apparel                sports bras
# 22      cell phones & accessories  cell phones & smartphones
# 23      cell phones & accessories         chargers & cradles
# 24                 tops & blouses                   t-shirts
# 25                          shoes                   athletic
# 26      cell phones & accessories      cases, covers & skins
# 27               athletic apparel    pants, tights, leggings
# 28                       swimwear                  one-piece
# 29                          jeans                   boot cut
# ...                           ...                        ...
# 693329                       toys   action figures & statues
# 693330                   sweaters                     hooded
# 693331                  diapering         disposable diapers
# 693332        women's accessories                 sunglasses
# 693333           athletic apparel                    jackets
# 693334                      shoes                      pumps
# 693335                    serving                        mug
# 693336                 home décor         home décor accents
# 693337              boys 0-24 mos            tops & t-shirts
# 693338                  underwear                       bras
# 693339                bath & body                       bath
# 693340        tools & accessories     makeup brushes & tools
# 693341        computers & tablets         laptops & netbooks
# 693342                    jewelry                   earrings
# 693343                     makeup                       face
# 693344                  skin care                       face
# 693345                       toys    stuffed animals & plush
# 693346                      shoes           fashion sneakers
# 693347                      shoes                      boots
# 693348           athletic apparel        tracksuits & sweats
# 693349                     makeup                       lips
# 693350                       toys                      games
# 693351                  boys (4+)             top & t-shirts
# 693352                   sweaters                   cardigan
# 693353                     makeup                       face
# 693354                 home décor         home décor accents
# 693355                     makeup                makeup sets
# 693356  cell phones & accessories      cases, covers & skins
# 693357                   swimwear                  cover-ups
# 693358             tops & blouses                   t-shirts
#
#                                   gen_subcat1 has_brand  \
# 0                                    men/tops     False
# 1             electronics/computers & tablets      True
# 2                        women/tops & blouses      True
# 3                             home/home décor     False
# 4                               women/jewelry     False
# 5                                 women/other     False
# 6                              women/swimwear      True
# 7                   sports & outdoors/apparel      True
# 8                   sports & outdoors/apparel      True
# 9         vintage & collectibles/collectibles     False
# 10                              beauty/makeup      True
# 11                           beauty/fragrance      True
# 12                              women/dresses      True
# 13                      other/office supplies      True
# 14                                women/shoes      True
# 15                              beauty/makeup      True
# 16                              beauty/makeup      True
# 17                                  kids/gear     False
# 18                              beauty/makeup      True
# 19                       women/tops & blouses      True
# 20                       women/tops & blouses      True
# 21                     women/athletic apparel      True
# 22      electronics/cell phones & accessories      True
# 23      electronics/cell phones & accessories     False
# 24                       women/tops & blouses      True
# 25                                  men/shoes      True
# 26      electronics/cell phones & accessories      True
# 27                     women/athletic apparel      True
# 28                             women/swimwear      True
# 29                                women/jeans      True
# ...                                       ...       ...
# 693329                              kids/toys      True
# 693330                         women/sweaters      True
# 693331                         kids/diapering     False
# 693332              women/women's accessories      True
# 693333                 women/athletic apparel     False
# 693334                            women/shoes      True
# 693335         vintage & collectibles/serving     False
# 693336                        home/home décor     False
# 693337                     kids/boys 0-24 mos      True
# 693338                        women/underwear      True
# 693339                     beauty/bath & body     False
# 693340             beauty/tools & accessories     False
# 693341        electronics/computers & tablets      True
# 693342                          women/jewelry     False
# 693343                          beauty/makeup      True
# 693344                       beauty/skin care      True
# 693345                              kids/toys      True
# 693346                            women/shoes      True
# 693347                            women/shoes      True
# 693348                 women/athletic apparel      True
# 693349                          beauty/makeup      True
# 693350                              kids/toys     False
# 693351                         kids/boys (4+)      True
# 693352                         women/sweaters      True
# 693353                          beauty/makeup      True
# 693354                        home/home décor     False
# 693355                          beauty/makeup      True
# 693356  electronics/cell phones & accessories     False
# 693357                         women/swimwear     False
# 693358                   women/tops & blouses     False
#
#                      gencat_cond                subcat_1_cond  \
# 0                          men_3                       tops_3
# 1                  electronics_3        computers & tablets_3
# 2                        women_1             tops & blouses_1
# 3                         home_1                 home décor_1
# 4                        women_1                    jewelry_1
# 5                        women_3                      other_3
# 6                        women_3                   swimwear_3
# 7            sports & outdoors_3                    apparel_3
# 8            sports & outdoors_3                    apparel_3
# 9       vintage & collectibles_3               collectibles_3
# 10                      beauty_2                     makeup_2
# 11                      beauty_1                  fragrance_1
# 12                       women_2                    dresses_2
# 13                       other_1            office supplies_1
# 14                       women_3                      shoes_3
# 15                      beauty_1                     makeup_1
# 16                      beauty_1                     makeup_1
# 17                        kids_1                       gear_1
# 18                      beauty_1                     makeup_1
# 19                       women_2             tops & blouses_2
# 20                       women_3             tops & blouses_3
# 21                       women_1           athletic apparel_1
# 22                 electronics_3  cell phones & accessories_3
# 23                 electronics_1  cell phones & accessories_1
# 24                       women_2             tops & blouses_2
# 25                         men_3                      shoes_3
# 26                 electronics_1  cell phones & accessories_1
# 27                       women_3           athletic apparel_3
# 28                       women_2                   swimwear_2
# 29                       women_3                      jeans_3
# ...                          ...                          ...
# 693329                    kids_3                       toys_3
# 693330                   women_2                   sweaters_2
# 693331                    kids_2                  diapering_2
# 693332                   women_2        women's accessories_2
# 693333                   women_3           athletic apparel_3
# 693334                   women_3                      shoes_3
# 693335  vintage & collectibles_5                    serving_5
# 693336                    home_1                 home décor_1
# 693337                    kids_3              boys 0-24 mos_3
# 693338                   women_3                  underwear_3
# 693339                  beauty_1                bath & body_1
# 693340                  beauty_1        tools & accessories_1
# 693341             electronics_4        computers & tablets_4
# 693342                   women_1                    jewelry_1
# 693343                  beauty_3                     makeup_3
# 693344                  beauty_1                  skin care_1
# 693345                    kids_3                       toys_3
# 693346                   women_3                      shoes_3
# 693347                   women_1                      shoes_1
# 693348                   women_1           athletic apparel_1
# 693349                  beauty_1                     makeup_1
# 693350                    kids_1                       toys_1
# 693351                    kids_1                  boys (4+)_1
# 693352                   women_3                   sweaters_3
# 693353                  beauty_3                     makeup_3
# 693354                    home_1                 home décor_1
# 693355                  beauty_1                     makeup_1
# 693356             electronics_1  cell phones & accessories_1
# 693357                   women_2                   swimwear_2
# 693358                   women_2             tops & blouses_2
#
#                       subcat_2_cond
# 0                        t-shirts_3
# 1              components & parts_3
# 2                          blouse_1
# 3              home décor accents_1
# 4                       necklaces_1
# 5                           other_3
# 6                       two-piece_3
# 7                           girls_3
# 8                           girls_3
# 9                            doll_3
# 10                           face_2
# 11                          women_1
# 12               above knee, mini_2
# 13                school supplies_1
# 14                          boots_3
# 15                    makeup sets_1
# 16                           eyes_1
# 17           backpacks & carriers_1
# 18                makeup palettes_1
# 19                         blouse_2
# 20                     tank, cami_3
# 21                    sports bras_1
# 22      cell phones & smartphones_3
# 23             chargers & cradles_1
# 24                       t-shirts_2
# 25                       athletic_3
# 26          cases, covers & skins_1
# 27        pants, tights, leggings_3
# 28                      one-piece_2
# 29                       boot cut_3
# ...                             ...
# 693329   action figures & statues_3
# 693330                     hooded_2
# 693331         disposable diapers_2
# 693332                 sunglasses_2
# 693333                    jackets_3
# 693334                      pumps_3
# 693335                        mug_5
# 693336         home décor accents_1
# 693337            tops & t-shirts_3
# 693338                       bras_3
# 693339                       bath_1
# 693340     makeup brushes & tools_1
# 693341         laptops & netbooks_4
# 693342                   earrings_1
# 693343                       face_3
# 693344                       face_1
# 693345    stuffed animals & plush_3
# 693346           fashion sneakers_3
# 693347                      boots_1
# 693348        tracksuits & sweats_1
# 693349                       lips_1
# 693350                      games_1
# 693351             top & t-shirts_1
# 693352                   cardigan_3
# 693353                       face_3
# 693354         home décor accents_1
# 693355                makeup sets_1
# 693356      cases, covers & skins_1
# 693357                  cover-ups_2
# 693358                   t-shirts_2
#
# [2175020 rows x 18 columns]

# %%
merge['name'] = merge['name'] + ' ' + merge['brand_name']
print(f'[{time() - start_time}] Name concancenated.')
# Out:
# [191.2796459197998] Name concancenated.

# %%
merge['item_description'] = merge['item_description'] \
                                + ' ' + merge['name'] \
                                + ' ' + merge['subcat_1'] \
                                + ' ' + merge['subcat_2'] \
                                + ' ' + merge['general_cat'] \
                                + ' ' + merge['brand_name']

# %%
print(f'[{time() - start_time}] Item description concatenated.')
# Out:
# [224.10888504981995] Item description concatenated.

# %%
merge.drop(['price', 'test_id', 'train_id'], axis=1, inplace=True)

# %%
merge
# Out:
#                brand_name                                      category_name  \
# 0                     mlb                                  men/tops/t-shirts
# 1                   razer  electronics/computers & tablets/components & p...
# 2                  target                        women/tops & blouses/blouse
# 3                                         home/home décor/home décor accents
# 4                complete                            women/jewelry/necklaces
# 5         banana republic                                  women/other/other
# 6         acacia swimwear                           women/swimwear/two-piece
# 7                   soffe                    sports & outdoors/apparel/girls
# 8                    nike                    sports & outdoors/apparel/girls
# 9                      so           vintage & collectibles/collectibles/doll
# 10               smashbox                                 beauty/makeup/face
# 11      victoria's secret                             beauty/fragrance/women
# 12                    rue                     women/dresses/above knee, mini
# 13             scholastic              other/office supplies/school supplies
# 14          ugg australia                                  women/shoes/boots
# 15                  tarte                          beauty/makeup/makeup sets
# 16             wet n wild                                 beauty/makeup/eyes
# 17                 active                     kids/gear/backpacks & carriers
# 18              too faced                      beauty/makeup/makeup palettes
# 19          anthropologie                        women/tops & blouses/blouse
# 20                 torrid                    women/tops & blouses/tank, cami
# 21      victoria's secret                 women/athletic apparel/sports bras
# 22                samsung  electronics/cell phones & accessories/cell pho...
# 23                    all  electronics/cell phones & accessories/chargers...
# 24             forever 21                      women/tops & blouses/t-shirts
# 25             air jordan                                 men/shoes/athletic
# 26                  apple  electronics/cell phones & accessories/cases, c...
# 27                lularoe     women/athletic apparel/pants, tights, leggings
# 28             forever 21                           women/swimwear/one-piece
# 29              hollister                               women/jeans/boot cut
# ...                   ...                                                ...
# 693329     mcfarlane toys                 kids/toys/action figures & statues
# 693330               nike                              women/sweaters/hooded
# 693331                                     kids/diapering/disposable diapers
# 693332              coach               women/women's accessories/sunglasses
# 693333                                        women/athletic apparel/jackets
# 693334         tory burch                                  women/shoes/pumps
# 693335                                    vintage & collectibles/serving/mug
# 693336                and                 home/home décor/home décor accents
# 693337                gap                 kids/boys 0-24 mos/tops & t-shirts
# 693338  victoria's secret                               women/underwear/bras
# 693339                all                            beauty/bath & body/bath
# 693340                     beauty/tools & accessories/makeup brushes & tools
# 693341              apple  electronics/computers & tablets/laptops & netb...
# 693342             silver                             women/jewelry/earrings
# 693343        bobbi brown                                 beauty/makeup/face
# 693344            kiehl's                              beauty/skin care/face
# 693345             disney                  kids/toys/stuffed animals & plush
# 693346             adidas                       women/shoes/fashion sneakers
# 693347       calvin klein                                  women/shoes/boots
# 693348               pink         women/athletic apparel/tracksuits & sweats
# 693349                nyx                                 beauty/makeup/lips
# 693350                and                                    kids/toys/games
# 693351           old navy                      kids/boys (4+)/top & t-shirts
# 693352            express                            women/sweaters/cardigan
# 693353        urban decay                                 beauty/makeup/face
# 693354                and                 home/home décor/home décor accents
# 693355       it cosmetics                          beauty/makeup/makeup sets
# 693356             galaxy  electronics/cell phones & accessories/cases, c...
# 693357                                              women/swimwear/cover-ups
# 693358                                         women/tops & blouses/t-shirts
#
#        item_condition_id                                   item_description  \
# 0                      3  no description yet mlb cincinnati reds t shirt...
# 1                      3  this keyboard is in great condition and works ...
# 2                      1  adorable top with a hint of lace and a key hol...
# 3                      1  new with tags. leather horses. retail for [rm]...
# 4                      1  complete with certificate of authenticity 24k ...
# 5                      3  banana republic bottoms, candies skirt with ma...
# 6                      3  size small but straps slightly shortened to fi...
# 7                      3  you get three pairs of sophie cheer shorts siz...
# 8                      3  girls size small plus green. three shorts tota...
# 9                      3  i realized his pants are on backwards after th...
# 10                     2  0.25oz full size is 1oz for [rm] in sephora sm...
# 11                     1  (5) new vs pink body mists (2.5oz each) fresh ...
# 12                     2  xl, great condition black skater dress rue dre...
# 13                     1  no description yet sharpener and eraser schola...
# 14                     3  authentic. suede fringe boots. great condition...
# 15                     1  brand new. deluxe travel size products. contai...
# 16                     1  2 glitter eyeshadows; one in brass and one in ...
# 17                     1  brand new in box size: medium color: coral ret...
# 18                     1  this authentic pallete by too faced is brand n...
# 19                     2  fancy, dressy or casual! dress it up or down 1...
# 20                     3  size 1. worn once. excellent condition torrid ...
# 21                     1  nwt victoria's secret ultimate sport bra -maxi...
# 22                     3  reasonable offers welcomed. but if you ask "lo...
# 23                     1  brand new never used all colors are available ...
# 24                     2  lanascloset ~~~ description: never worn! ✨ i d...
# 25                     3  they are 100 percent authentic. they are beate...
# 26                     1  brand new otterbox defender iphone 6 plus/6s p...
# 27                     3  worn one time. excellent condition lularoe os ...
# 28                     2  beautiful excellent condition zips and ties in...
# 29                     3  29w. x 33l. social stretch hollister jeans ***...
# ...                  ...                                                ...
# 693329                 3  5 action figures halo mcfarlane no accesories ...
# 693330                 2  hi this is a large woman's therma-fit pullover...
# 693331                 2  like new 23 unisex diapers size newborn  diape...
# 693332                 2  nwot coach delphine tortoise shell sunglasses,...
# 693333                 3  imitation leather white in good condition wome...
# 693334                 3  rare authentic size 6.5 tory burch wedges. sho...
# 693335                 5  no description yet hi-c mug  serving mug vinta...
# 693336                 1  100% organic & it really works! incredible for...
# 693337                 3  last chance before they go to consignment! var...
# 693338                 3  size 34b vs bra victoria's secret underwear br...
# 693339                 1  from their beetlejuice collection! collection ...
# 693340                 1  free shipping eyecat smokey eyeliner stencil t...
# 693341                 4  macbook 13" i7 2011 this laptop is in working ...
# 693342                 1  please follow me for new listings. this site n...
# 693343                 3  this is a stay all day, lightweight foundation...
# 693344                 1  brand new in box kiehl's midnight recovery con...
# 693345                 3  disney store exclusive marie about 10 inches l...
# 693346                 3  adidas tubular invader strap size 9in women us...
# 693347                 1  size 8 i'm a 8.5 and they fit me worn once for...
# 693348                 1  large strappy leggings and large bling campus ...
# 693349                 1  ❗️listing is for 1❗️ brand new shades piu05 sc...
# 693350                 1  [rm] free shipping too new and highly addictiv...
# 693351                 1  purple boys polo shirt in size 10/12. old navy...
# 693352                 3  express deep olive green cardigan | ultra thin...
# 693353                 3  in the shade medium neutral. barley used. urba...
# 693354                 1  flint/quartz cluster. self mined ✨measures 3x2...
# 693355                 1  it cosmetics travel bundle. includes: brow pow...
# 693356                 1  new. free shipping basstop case galaxy s8 hard...
# 693357                 2  floral kimono. tropical print. open front. hi ...
# 693358                 2  2 floral scrub tops. worn less than 5 times ea...
#
#                                                      name shipping  \
# 0                 mlb cincinnati reds t shirt size xl mlb        1
# 1                  razer blackwidow chroma keyboard razer        0
# 2                                   ava-viv blouse target        1
# 3                                  leather horse statues         1
# 4                           24k gold plated rose complete        0
# 5        bundled items requested for ruie banana republic        0
# 6       acacia pacific tides santorini top acacia swim...        0
# 7              girls cheer and tumbling bundle of 7 soffe        1
# 8                              girls nike pro shorts nike        0
# 9               porcelain clown doll checker pants vtg so        0
# 10                               smashbox primer smashbox        1
# 11               new vs pi k body mists victoria's secret        0
# 12                                 black skater dress rue        0
# 13                        sharpener and eraser scholastic        1
# 14       hold for dogs2016 minnetonka boots ugg australia        0
# 15                      sephora tarte birthday gift tarte        1
# 16                           glitter eyeshadow wet n wild        1
# 17             new: baby k'tan active baby carrier active        1
# 18          too faced limited "merry macaroons" too faced        1
# 19           cream/ beige front cross shirt anthropologie        0
# 20                 torrid nautical peplum tube top torrid        1
# 21      nwt vs ultimate sports bra 34ddd victoria's se...        0
# 22                 galaxy s7 edge (unlocked) 32gb samsung        0
# 23                                 triple car charger all        1
# 24                  black and red baseball tee forever 21        0
# 25                       air jordan carmine 6s air jordan        0
# 26          otterbox defender iphone 6 plus/6s plus apple        1
# 27         lularoe os black with white polka dots lularoe        0
# 28           forever21 floral romper strapless forever 21        1
# 29                                kendra bundle hollister        1
# ...                                                   ...      ...
# 693329     lot 5 acción figures macfarlane mcfarlane toys        0
# 693330                      nike hoodie just do it l nike        1
# 693331                    23 unisex diapers size newborn         0
# 693332      nwot coach "delphine" sunglasses w/case coach        1
# 693333                             womems leather jacket         0
# 693334                   tory burch 6.5 wedges tory burch        0
# 693335                                          hi-c mug         0
# 693336         removes coffee stains & yellow teeth!! and        1
# 693337            must go! lot of toddler boy clothes gap        0
# 693338                           vs bra victoria's secret        0
# 693339                            fortune cookie soap all        0
# 693340           2pcs eyecat smokey eyeliner stencil set         1
# 693341                              macbook pro 13" apple        0
# 693342        sterling silver triangle cz earrings silver        1
# 693343     bobbi brown warm ivory foundation. bobbi brown        0
# 693344      kiehl's midnight recovery concentrate kiehl's        0
# 693345                          disney store marie disney        0
# 693346                adidas tubular invader strap adidas        1
# 693347       calvin klein booties heel boots calvin klein        0
# 693348                                 bundle add on pink        1
# 693349                                nyx lip plumper nyx        1
# 693350          new fidget hand spinner desk toy cube and        1
# 693351            boys polo shirt in size 10/12. old navy        0
# 693352          express deep olive green cardigan express        1
# 693353                urban decay face powder urban decay        1
# 693354                  quartz crystal on flint stone and        0
# 693355          it cosmetics - travel bundle it cosmetics        1
# 693356                   galaxy s8 hard shell case galaxy        1
# 693357                              hi low floral kimono         0
# 693358             freeship 2 floral scrub tops, medium.         1
#
#        has_category             general_cat                   subcat_1  \
# 0              True                     men                       tops
# 1              True             electronics        computers & tablets
# 2              True                   women             tops & blouses
# 3              True                    home                 home décor
# 4              True                   women                    jewelry
# 5              True                   women                      other
# 6              True                   women                   swimwear
# 7              True       sports & outdoors                    apparel
# 8              True       sports & outdoors                    apparel
# 9              True  vintage & collectibles               collectibles
# 10             True                  beauty                     makeup
# 11             True                  beauty                  fragrance
# 12             True                   women                    dresses
# 13             True                   other            office supplies
# 14             True                   women                      shoes
# 15             True                  beauty                     makeup
# 16             True                  beauty                     makeup
# 17             True                    kids                       gear
# 18             True                  beauty                     makeup
# 19             True                   women             tops & blouses
# 20             True                   women             tops & blouses
# 21             True                   women           athletic apparel
# 22             True             electronics  cell phones & accessories
# 23             True             electronics  cell phones & accessories
# 24             True                   women             tops & blouses
# 25             True                     men                      shoes
# 26             True             electronics  cell phones & accessories
# 27             True                   women           athletic apparel
# 28             True                   women                   swimwear
# 29             True                   women                      jeans
# ...             ...                     ...                        ...
# 693329         True                    kids                       toys
# 693330         True                   women                   sweaters
# 693331         True                    kids                  diapering
# 693332         True                   women        women's accessories
# 693333         True                   women           athletic apparel
# 693334         True                   women                      shoes
# 693335         True  vintage & collectibles                    serving
# 693336         True                    home                 home décor
# 693337         True                    kids              boys 0-24 mos
# 693338         True                   women                  underwear
# 693339         True                  beauty                bath & body
# 693340         True                  beauty        tools & accessories
# 693341         True             electronics        computers & tablets
# 693342         True                   women                    jewelry
# 693343         True                  beauty                     makeup
# 693344         True                  beauty                  skin care
# 693345         True                    kids                       toys
# 693346         True                   women                      shoes
# 693347         True                   women                      shoes
# 693348         True                   women           athletic apparel
# 693349         True                  beauty                     makeup
# 693350         True                    kids                       toys
# 693351         True                    kids                  boys (4+)
# 693352         True                   women                   sweaters
# 693353         True                  beauty                     makeup
# 693354         True                    home                 home décor
# 693355         True                  beauty                     makeup
# 693356         True             electronics  cell phones & accessories
# 693357         True                   women                   swimwear
# 693358         True                   women             tops & blouses
#
#                          subcat_2                            gen_subcat1  \
# 0                        t-shirts                               men/tops
# 1              components & parts        electronics/computers & tablets
# 2                          blouse                   women/tops & blouses
# 3              home décor accents                        home/home décor
# 4                       necklaces                          women/jewelry
# 5                           other                            women/other
# 6                       two-piece                         women/swimwear
# 7                           girls              sports & outdoors/apparel
# 8                           girls              sports & outdoors/apparel
# 9                            doll    vintage & collectibles/collectibles
# 10                           face                          beauty/makeup
# 11                          women                       beauty/fragrance
# 12               above knee, mini                          women/dresses
# 13                school supplies                  other/office supplies
# 14                          boots                            women/shoes
# 15                    makeup sets                          beauty/makeup
# 16                           eyes                          beauty/makeup
# 17           backpacks & carriers                              kids/gear
# 18                makeup palettes                          beauty/makeup
# 19                         blouse                   women/tops & blouses
# 20                     tank, cami                   women/tops & blouses
# 21                    sports bras                 women/athletic apparel
# 22      cell phones & smartphones  electronics/cell phones & accessories
# 23             chargers & cradles  electronics/cell phones & accessories
# 24                       t-shirts                   women/tops & blouses
# 25                       athletic                              men/shoes
# 26          cases, covers & skins  electronics/cell phones & accessories
# 27        pants, tights, leggings                 women/athletic apparel
# 28                      one-piece                         women/swimwear
# 29                       boot cut                            women/jeans
# ...                           ...                                    ...
# 693329   action figures & statues                              kids/toys
# 693330                     hooded                         women/sweaters
# 693331         disposable diapers                         kids/diapering
# 693332                 sunglasses              women/women's accessories
# 693333                    jackets                 women/athletic apparel
# 693334                      pumps                            women/shoes
# 693335                        mug         vintage & collectibles/serving
# 693336         home décor accents                        home/home décor
# 693337            tops & t-shirts                     kids/boys 0-24 mos
# 693338                       bras                        women/underwear
# 693339                       bath                     beauty/bath & body
# 693340     makeup brushes & tools             beauty/tools & accessories
# 693341         laptops & netbooks        electronics/computers & tablets
# 693342                   earrings                          women/jewelry
# 693343                       face                          beauty/makeup
# 693344                       face                       beauty/skin care
# 693345    stuffed animals & plush                              kids/toys
# 693346           fashion sneakers                            women/shoes
# 693347                      boots                            women/shoes
# 693348        tracksuits & sweats                 women/athletic apparel
# 693349                       lips                          beauty/makeup
# 693350                      games                              kids/toys
# 693351             top & t-shirts                         kids/boys (4+)
# 693352                   cardigan                         women/sweaters
# 693353                       face                          beauty/makeup
# 693354         home décor accents                        home/home décor
# 693355                makeup sets                          beauty/makeup
# 693356      cases, covers & skins  electronics/cell phones & accessories
# 693357                  cover-ups                         women/swimwear
# 693358                   t-shirts                   women/tops & blouses
#
#        has_brand               gencat_cond                subcat_1_cond  \
# 0          False                     men_3                       tops_3
# 1           True             electronics_3        computers & tablets_3
# 2           True                   women_1             tops & blouses_1
# 3          False                    home_1                 home décor_1
# 4          False                   women_1                    jewelry_1
# 5          False                   women_3                      other_3
# 6           True                   women_3                   swimwear_3
# 7           True       sports & outdoors_3                    apparel_3
# 8           True       sports & outdoors_3                    apparel_3
# 9          False  vintage & collectibles_3               collectibles_3
# 10          True                  beauty_2                     makeup_2
# 11          True                  beauty_1                  fragrance_1
# 12          True                   women_2                    dresses_2
# 13          True                   other_1            office supplies_1
# 14          True                   women_3                      shoes_3
# 15          True                  beauty_1                     makeup_1
# 16          True                  beauty_1                     makeup_1
# 17         False                    kids_1                       gear_1
# 18          True                  beauty_1                     makeup_1
# 19          True                   women_2             tops & blouses_2
# 20          True                   women_3             tops & blouses_3
# 21          True                   women_1           athletic apparel_1
# 22          True             electronics_3  cell phones & accessories_3
# 23         False             electronics_1  cell phones & accessories_1
# 24          True                   women_2             tops & blouses_2
# 25          True                     men_3                      shoes_3
# 26          True             electronics_1  cell phones & accessories_1
# 27          True                   women_3           athletic apparel_3
# 28          True                   women_2                   swimwear_2
# 29          True                   women_3                      jeans_3
# ...          ...                       ...                          ...
# 693329      True                    kids_3                       toys_3
# 693330      True                   women_2                   sweaters_2
# 693331     False                    kids_2                  diapering_2
# 693332      True                   women_2        women's accessories_2
# 693333     False                   women_3           athletic apparel_3
# 693334      True                   women_3                      shoes_3
# 693335     False  vintage & collectibles_5                    serving_5
# 693336     False                    home_1                 home décor_1
# 693337      True                    kids_3              boys 0-24 mos_3
# 693338      True                   women_3                  underwear_3
# 693339     False                  beauty_1                bath & body_1
# 693340     False                  beauty_1        tools & accessories_1
# 693341      True             electronics_4        computers & tablets_4
# 693342     False                   women_1                    jewelry_1
# 693343      True                  beauty_3                     makeup_3
# 693344      True                  beauty_1                  skin care_1
# 693345      True                    kids_3                       toys_3
# 693346      True                   women_3                      shoes_3
# 693347      True                   women_1                      shoes_1
# 693348      True                   women_1           athletic apparel_1
# 693349      True                  beauty_1                     makeup_1
# 693350     False                    kids_1                       toys_1
# 693351      True                    kids_1                  boys (4+)_1
# 693352      True                   women_3                   sweaters_3
# 693353      True                  beauty_3                     makeup_3
# 693354     False                    home_1                 home décor_1
# 693355      True                  beauty_1                     makeup_1
# 693356     False             electronics_1  cell phones & accessories_1
# 693357     False                   women_2                   swimwear_2
# 693358     False                   women_2             tops & blouses_2
#
#                       subcat_2_cond
# 0                        t-shirts_3
# 1              components & parts_3
# 2                          blouse_1
# 3              home décor accents_1
# 4                       necklaces_1
# 5                           other_3
# 6                       two-piece_3
# 7                           girls_3
# 8                           girls_3
# 9                            doll_3
# 10                           face_2
# 11                          women_1
# 12               above knee, mini_2
# 13                school supplies_1
# 14                          boots_3
# 15                    makeup sets_1
# 16                           eyes_1
# 17           backpacks & carriers_1
# 18                makeup palettes_1
# 19                         blouse_2
# 20                     tank, cami_3
# 21                    sports bras_1
# 22      cell phones & smartphones_3
# 23             chargers & cradles_1
# 24                       t-shirts_2
# 25                       athletic_3
# 26          cases, covers & skins_1
# 27        pants, tights, leggings_3
# 28                      one-piece_2
# 29                       boot cut_3
# ...                             ...
# 693329   action figures & statues_3
# 693330                     hooded_2
# 693331         disposable diapers_2
# 693332                 sunglasses_2
# 693333                    jackets_3
# 693334                      pumps_3
# 693335                        mug_5
# 693336         home décor accents_1
# 693337            tops & t-shirts_3
# 693338                       bras_3
# 693339                       bath_1
# 693340     makeup brushes & tools_1
# 693341         laptops & netbooks_4
# 693342                   earrings_1
# 693343                       face_3
# 693344                       face_1
# 693345    stuffed animals & plush_3
# 693346           fashion sneakers_3
# 693347                      boots_1
# 693348        tracksuits & sweats_1
# 693349                       lips_1
# 693350                      games_1
# 693351             top & t-shirts_1
# 693352                   cardigan_3
# 693353                       face_3
# 693354         home décor accents_1
# 693355                makeup sets_1
# 693356      cases, covers & skins_1
# 693357                  cover-ups_2
# 693358                   t-shirts_2
#
# [2175020 rows x 15 columns]

# %%
nrow_train
# Out:
# 1481661

# %%
y_train
# Out:
# 0          2.397895
# 1          3.970292
# 2          2.397895
# 3          3.583519
# 4          3.806662
# 5          4.094345
# 6          4.174387
# 7          1.945910
# 8          2.995732
# 9          2.197225
# 10         2.197225
# 11         3.555348
# 12         2.833213
# 13         1.609438
# 14         3.784190
# 15         2.484907
# 16         1.945910
# 17         3.401197
# 18         3.258097
# 19         3.332205
# 20         2.639057
# 21         3.044522
# 22         5.958425
# 23         2.197225
# 24         2.397895
# 25         4.204693
# 26         2.639057
# 27         3.218876
# 28         1.791759
# 29         2.833213
#              ...
# 1481631    3.555348
# 1481632    5.111988
# 1481633    3.218876
# 1481634    3.091042
# 1481635    4.564348
# 1481636    2.302585
# 1481637    1.791759
# 1481638    3.555348
# 1481639    1.791759
# 1481640    3.178054
# 1481641    3.044522
# 1481642    2.772589
# 1481643    2.484907
# 1481644    2.397895
# 1481645    2.302585
# 1481646    2.944439
# 1481647    2.302585
# 1481648    2.197225
# 1481649    2.197225
# 1481650    3.295837
# 1481651    2.079442
# 1481652    2.564949
# 1481653    2.397895
# 1481654    2.944439
# 1481655    3.555348
# 1481656    3.044522
# 1481657    2.708050
# 1481658    2.564949
# 1481659    3.828641
# 1481660    3.135494
# Name: price, Length: 1481661, dtype: float64

# %%
meta_params = {'name_ngram': (1, 2),
                   'name_max_f': 75000,
                   'name_min_df': 10,

                   'category_ngram': (2, 3),
                   'category_token': '.+',
                   'category_min_df': 10,

                   'brand_min_df': 10,

                   'desc_ngram': (1, 3),
                   'desc_max_f': 150000,
                   'desc_max_df': 0.5,
                   'desc_min_df': 10}
stopwords = frozenset(['the', 'a', 'an', 'is', 'it', 'this', ])

# %%
stopwords
# Out:
# frozenset({'a', 'an', 'is', 'it', 'the', 'this'})

# %%
vectorizer = FeatureUnion([
        ('name', Pipeline([
            ('select', ItemSelector('name', start_time=start_time)),
            ('transform', HashingVectorizer(
                ngram_range=(1, 2),
                n_features=2 ** 27,
                norm='l2',
                lowercase=False,
                stop_words=stopwords
            )),
            ('drop_cols', DropColumnsByDf(min_df=2))
        ])),
        ('category_name', Pipeline([
            ('select', ItemSelector('category_name', start_time=start_time)),
            ('transform', HashingVectorizer(
                ngram_range=(1, 1),
                token_pattern='.+',
                tokenizer=split_cat,
                n_features=2 ** 27,
                norm='l2',
                lowercase=False
            )),
            ('drop_cols', DropColumnsByDf(min_df=2))
        ])),
        ('brand_name', Pipeline([
            ('select', ItemSelector('brand_name', start_time=start_time)),
            ('transform', CountVectorizer(
                token_pattern='.+',
                min_df=2,
                lowercase=False
            )),
        ])),
        ('gencat_cond', Pipeline([
            ('select', ItemSelector('gencat_cond', start_time=start_time)),
            ('transform', CountVectorizer(
                token_pattern='.+',
                min_df=2,
                lowercase=False
            )),
        ])),
        ('subcat_1_cond', Pipeline([
            ('select', ItemSelector('subcat_1_cond', start_time=start_time)),
            ('transform', CountVectorizer(
                token_pattern='.+',
                min_df=2,
                lowercase=False
            )),
        ])),
        ('subcat_2_cond', Pipeline([
            ('select', ItemSelector('subcat_2_cond', start_time=start_time)),
            ('transform', CountVectorizer(
                token_pattern='.+',
                min_df=2,
                lowercase=False
            )),
        ])),
        ('has_brand', Pipeline([
            ('select', ItemSelector('has_brand', start_time=start_time)),
            ('ohe', OneHotEncoder())
        ])),
        ('shipping', Pipeline([
            ('select', ItemSelector('shipping', start_time=start_time)),
            ('ohe', OneHotEncoder())
        ])),
        ('item_condition_id', Pipeline([
            ('select', ItemSelector('item_condition_id', start_time=start_time)),
            ('ohe', OneHotEncoder())
        ])),
        ('item_description', Pipeline([
            ('select', ItemSelector('item_description', start_time=start_time)),
            ('hash', HashingVectorizer(
                ngram_range=(1, 3),
                n_features=2 ** 27,
                dtype=np.float32,
                norm='l2',
                lowercase=False,
                stop_words=stopwords
            )),
            ('drop_cols', DropColumnsByDf(min_df=2)),
        ]))
    ], n_jobs=1)

# %% [markdown]
# mergeを文字列カウント、one-hotへ変換
#
# sparse行列で保持

# %%
sparse_merge = vectorizer.fit_transform(merge)
print(f'[{time() - start_time}] Merge vectorized')
print(sparse_merge.shape)
# Out:
# [226.27710628509521] select name
# [303.3740816116333] select category_name
# [334.99943590164185] select brand_name
# [348.80674839019775] select gencat_cond
# [355.92183113098145] select subcat_1_cond
# [363.2626166343689] select subcat_2_cond
# [370.66668367385864] select has_brand
# [371.0802159309387] select shipping
# [371.30441451072693] select item_condition_id
# [371.5399785041809] select item_description
# [912.8547670841217] Merge vectorized
# (2175020, 8961796)

# %%
sparse_merge
# Out:
# <2175020x8961796 sparse matrix of type '<class 'numpy.float64'>'
# 	with 217904545 stored elements in Compressed Sparse Row format>

# %%
tfidf_transformer = TfidfTransformer()

# %%
X = tfidf_transformer.fit_transform(sparse_merge)
print(f'[{time() - start_time}] TF/IDF completed')
# Out:
# [1136.3087015151978] TF/IDF completed

# %%
X
# Out:
# <2175020x8961796 sparse matrix of type '<class 'numpy.float64'>'
# 	with 217904545 stored elements in Compressed Sparse Row format>

# %% [markdown]
# 上側にTraining data

# %%
X_train = X[:nrow_train]
print(X_train.shape)
# Out:
# (1481661, 8961796)

# %% [markdown]
# 下側にTest data

# %%
X_test = X[nrow_train:]

# %%
print(X_test.shape)
# Out:
# (693359, 8961796)

# %%
del merge
del sparse_merge
del vectorizer
del tfidf_transformer
gc.collect()
# Out:
# 17

# %%
X_train, X_test = intersect_drop_columns(X_train, X_test, min_df=1)
print(f'[{time() - start_time}] Drop only in train or test cols: {X_train.shape[1]}')
gc.collect()
# Out:
# [1350.0133435726166] Drop only in train or test cols: 5976503
# 0

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1481661, 5976503)
# (693359, 5976503)

# %% [markdown]
# <h1>Training and predict

# %%
ridge = Ridge(solver='auto', fit_intercept=True, alpha=0.4, max_iter=200, normalize=False, tol=0.01)
ridge.fit(X_train, y_train)
print(f'[{time() - start_time}] Train Ridge completed. Iterations: {ridge.n_iter_}')
# Out:
# [1556.4994559288025] Train Ridge completed. Iterations: [17]

# %%
predsR = ridge.predict(X_test)
print(f'[{time() - start_time}] Predict Ridge completed.')
# Out:
# [1562.4838631153107] Predict Ridge completed.

# %%
submission.loc[:, 'price'] = np.expm1(predsR)
submission.loc[submission['price'] < 0.0, 'price'] = 0.0
submission.to_csv("submission_ridge.csv", index=False)
